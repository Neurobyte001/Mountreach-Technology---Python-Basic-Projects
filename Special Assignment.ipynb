# %% [markdown]
# # Special Assignment
#
# # Kaggle Dataset Analysis & Visualization
#
# ### Name: Prathmesh Sanjay Manwar
#
# ### Department: Artificial Intelligence & Machine Learning (AIML)
#
# ##### Dataset:
# ##### Titanic Dataset
#
# Dataset Source:
# https://www.kaggle.com/datasets/yasserh/titanic-dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
# Loading the Titanic dataset
df = pd.read_csv("Titanic-Dataset.csv")

# Displaying first 10 rows
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Dataset Shape

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Column Names

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Visualization Section
#
# ### Histogram

# %%
sns.histplot(df["Age"], bins=20, kde=True)
plt.title("Distribution of Passenger Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Gender Distribution (Count Plot)

# %%
sns.countplot(x="Sex", data=df)
plt.title("Male vs Female Passengers")
plt.show()

# %% [markdown]
# ### Passenger Class Distribution (Count Plot)

# %%
sns.countplot(x="Pclass", data=df)
plt.title("Passenger Class Distribution")
plt.show()

# %% [markdown]
# ### Fare Distribution by Passenger Class (Box Plot)

# %%
sns.boxplot(x="Pclass", y="Fare", data=df)
plt.title("Fare Distribution by Passenger Class")
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.Figure(figsize=(10, 6))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Survival Percentage (Pie Chart)

# %%
df["Survived"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    labels=["Did Not Survive","Survived"]
)

plt.title("Survival Percentage")

plt.ylabel("")

plt.show()

# %% [markdown]
# ### Key Insights
#
# • The dataset contains information about Titanic passengers, including age, gender, ticket class, fare, and survival status.
#
# • Most passengers belonged to the third passenger class.
#
# • Male passengers were more numerous than female passengers.
#
# • Higher passenger class generally corresponds to higher ticket fares.
#
# • The dataset contains some missing values in columns such as Age and Cabin.
#
# • Correlation analysis shows that passenger class and fare have a relationship with survival.

# %% [markdown]
# # Dataset Name
#
# #### Titanic Dataset Analysis & Visualization
#
# ## Kaggle Link
#
# https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# ## Description
#
# The Titanic dataset contains passenger information such as age, gender, ticket class, fare, cabin details, and survival status. It is commonly used for data analysis and binary classification tasks.
#
# ## Rows
#
# 918
#
# ## Columns
#
# 12
#
# ## Features
#
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
#
# ## Input Features
#
# All except HeartDisease
#
# ## Target Feature
#
# HeartDisease
#
# ## Machine Learning Problem
#
# Classification
#
# ## Conclusion
#
# The Titanic dataset was successfully loaded and explored using Pandas. Various visualizations such as histograms, count plots, box plots, heatmaps, and pie charts were created to understand the relationships between different features. The analysis shows that factors such as passenger class, gender, and fare have an impact on survival. The dataset is well-suited for binary classification and serves as an excellent example for Exploratory Data Analysis (EDA).
